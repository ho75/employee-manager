# %%
import chardet
#بتعرفني لغة التشفير بتاعت ال dataset
with open("bi.csv", "rb") as f:
    result = chardet.detect(f.read(10000))
    print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
import pandas as pd
df = pd.read_csv("bi.csv", encoding="ISO-8859-1")
df.head(10)
# Out:
#        fNAME      lNAME  Age  gender       country     residence  entryEXAM  \
# 0  Christina     Binger   44  Female        Norway       Private         72
# 1       Alex   Walekhwa   60       M         Kenya       Private         79
# 2     Philip        Leo   25    Male        Uganda     Sognsvann         55
# 3      Shoni  Hlongwane   22       F           Rsa     Sognsvann         40
# 4      Maria   Kedibone   23  Female  South Africa     Sognsvann         65
# 5     Hannah     Hansen   25  female         Norge  BI Residence         66
# 6        Ole   Johansen   27    Male        Norway  BI-Residence         90
# 7       Lars      Olsen   29    Male        norway   BIResidence         89
# 8      Bjørn     Larsen   31    Male        Norway  BI Residence         88
# 9      Sofie     Jensen   33  Female       Denmark  BI_Residence         85
#
#   prevEducation  studyHOURS  Python  DB
# 0       Masters         158    59.0  55
# 1       Diploma         150    60.0  75
# ...

# %%
df.tail(10)
# Out:
#         fNAME    lNAME  Age  gender      country  residence  entryEXAM  \
# 67      Lucas  Schmidt   33    Male      Germany  Sognsvann         98
# 68      Marie   Dubois   35  Female       France  Sognsvann         69
# 69     Thomas   García   37    Male        Spain    Private         80
# 70       Emma  Janssen   39  Female  Netherlands    Private         81
# 71  Maximilan  Martini   50    Male        Italy    Private         74
# 72      Clara  Bernard   43  Female       France    Private         80
# 73     Julian  Nielsen   31    Male      Denmark  Sognsvann         90
# 74     Sophie    Brown   33  Female           UK  Sognsvann         96
# 75       Leon    Bauer   35    Male      Germany  Sognsvann         90
# 76   Mohammed    Salim   31    Male       Somali  Sognsvann         35
#
#    prevEducation  studyHOURS  Python  DB
# 67       Masters         160    87.0  86
# 68     Bachelors         144    69.0  45
# 69     Bachelors         152    78.0  62
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fNAME          77 non-null     object
#  1   lNAME          77 non-null     object
#  2   Age            77 non-null     int64
#  3   gender         77 non-null     object
#  4   country        77 non-null     object
#  5   residence      77 non-null     object
#  6   entryEXAM      77 non-null     int64
#  7   prevEducation  77 non-null     object
#  8   studyHOURS     77 non-null     int64
#  9   Python         75 non-null     float64
#  10  DB             77 non-null     int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 6.7+ KB

# %%
df.shape
# Out:
# (77, 11)

# %%
df['gender'].unique()
# Out:
# array(['Female', 'M', 'Male', 'F', 'female', 'male'], dtype=object)

# %%
df['prevEducation'].unique()
# Out:
# array(['Masters', 'Diploma', 'HighSchool', 'High School', 'Bachelors',
#        'Barrrchelors', 'diploma', 'DIPLOMA', 'Diplomaaa', 'Doctorate'],
#       dtype=object)

# %%
df['country'].unique()
# Out:
# array(['Norway', 'Kenya', 'Uganda', 'Rsa', 'South Africa', 'Norge',
#        'norway', 'Denmark', 'Netherlands', 'Italy', 'Spain', 'UK',
#        'Somali', 'Nigeria', 'Germany', 'France'], dtype=object)

# %%
df['residence'].unique()
# Out:
# array(['Private', 'Sognsvann', 'BI Residence', 'BI-Residence',
#        'BIResidence', 'BI_Residence'], dtype=object)

# %%
df['gender'] = df['gender'].replace({
    'M': 'Male',
    'MALE ': 'Male',
    ' f ': 'Female',
    'F': 'Female',
    'female': 'Female',
    'male' : 'Male'
})
df.head(15)
# Out:
#         fNAME      lNAME  Age  gender       country     residence  entryEXAM  \
# 0   Christina     Binger   44  Female        Norway       Private         72
# 1        Alex   Walekhwa   60    Male         Kenya       Private         79
# 2      Philip        Leo   25    Male        Uganda     Sognsvann         55
# 3       Shoni  Hlongwane   22  Female           Rsa     Sognsvann         40
# 4       Maria   Kedibone   23  Female  South Africa     Sognsvann         65
# 5      Hannah     Hansen   25  Female         Norge  BI Residence         66
# 6         Ole   Johansen   27    Male        Norway  BI-Residence         90
# 7        Lars      Olsen   29    Male        norway   BIResidence         89
# 8       Bjørn     Larsen   31    Male        Norway  BI Residence         88
# 9       Sofie     Jensen   33  Female       Denmark  BI_Residence         85
# 10       Emma   de Vries   34  Female   Netherlands  BI Residence         65
# ...

# %%
df['prevEducation']=df['prevEducation'].replace({
    'HighSchool': 'High School',
    'diploma' :  'Diploma',
    'DIPLOMA' : 'Diploma',
    'Diplomaaa' : 'Diploma',
    'Barrrchelors' : 'Bachelors'
})
df.head(15)
# Out:
#         fNAME      lNAME  Age  gender       country     residence  entryEXAM  \
# 0   Christina     Binger   44  Female        Norway       Private         72
# 1        Alex   Walekhwa   60    Male         Kenya       Private         79
# 2      Philip        Leo   25    Male        Uganda     Sognsvann         55
# 3       Shoni  Hlongwane   22  Female           Rsa     Sognsvann         40
# 4       Maria   Kedibone   23  Female  South Africa     Sognsvann         65
# 5      Hannah     Hansen   25  Female         Norge  BI Residence         66
# 6         Ole   Johansen   27    Male        Norway  BI-Residence         90
# 7        Lars      Olsen   29    Male        norway   BIResidence         89
# 8       Bjørn     Larsen   31    Male        Norway  BI Residence         88
# 9       Sofie     Jensen   33  Female       Denmark  BI_Residence         85
# 10       Emma   de Vries   34  Female   Netherlands  BI Residence         65
# ...

# %%
df['country'] = df['country'].replace({
    'norway': 'Norway'
})
df.head(15)
# Out:
#         fNAME      lNAME  Age  gender       country     residence  entryEXAM  \
# 0   Christina     Binger   44  Female        Norway       Private         72
# 1        Alex   Walekhwa   60    Male         Kenya       Private         79
# 2      Philip        Leo   25    Male        Uganda     Sognsvann         55
# 3       Shoni  Hlongwane   22  Female           Rsa     Sognsvann         40
# 4       Maria   Kedibone   23  Female  South Africa     Sognsvann         65
# 5      Hannah     Hansen   25  Female         Norge  BI Residence         66
# 6         Ole   Johansen   27    Male        Norway  BI-Residence         90
# 7        Lars      Olsen   29    Male        Norway   BIResidence         89
# 8       Bjørn     Larsen   31    Male        Norway  BI Residence         88
# 9       Sofie     Jensen   33  Female       Denmark  BI_Residence         85
# 10       Emma   de Vries   34  Female   Netherlands  BI Residence         65
# ...

# %%
df['residence']=df['residence'].replace({
    'BIResidence' : 'BI_Residence',
    'BI Residence' :  'BI_Residence',
    'BI-Residence' : 'BI_Residence'
})

df.head(15)
# Out:
#         fNAME      lNAME  Age  gender       country     residence  entryEXAM  \
# 0   Christina     Binger   44  Female        Norway       Private         72
# 1        Alex   Walekhwa   60    Male         Kenya       Private         79
# 2      Philip        Leo   25    Male        Uganda     Sognsvann         55
# 3       Shoni  Hlongwane   22  Female           Rsa     Sognsvann         40
# 4       Maria   Kedibone   23  Female  South Africa     Sognsvann         65
# 5      Hannah     Hansen   25  Female         Norge  BI_Residence         66
# 6         Ole   Johansen   27    Male        Norway  BI_Residence         90
# 7        Lars      Olsen   29    Male        Norway  BI_Residence         89
# 8       Bjørn     Larsen   31    Male        Norway  BI_Residence         88
# 9       Sofie     Jensen   33  Female       Denmark  BI_Residence         85
# 10       Emma   de Vries   34  Female   Netherlands  BI_Residence         65
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
 df.drop_duplicates()
# Out:
#         fNAME      lNAME  Age  gender       country  residence  entryEXAM  \
# 0   Christina     Binger   44  Female        Norway    Private         72
# 1        Alex   Walekhwa   60    Male         Kenya    Private         79
# 2      Philip        Leo   25    Male        Uganda  Sognsvann         55
# 3       Shoni  Hlongwane   22  Female           Rsa  Sognsvann         40
# 4       Maria   Kedibone   23  Female  South Africa  Sognsvann         65
# ..        ...        ...  ...     ...           ...        ...        ...
# 72      Clara    Bernard   43  Female        France    Private         80
# 73     Julian    Nielsen   31    Male       Denmark  Sognsvann         90
# 74     Sophie      Brown   33  Female            UK  Sognsvann         96
# 75       Leon      Bauer   35    Male       Germany  Sognsvann         90
# 76   Mohammed      Salim   31    Male        Somali  Sognsvann         35
#
#    prevEducation  studyHOURS  Python  DB
# ...

# %%
 df.isnull().sum()
# Out:
# fNAME            0
# lNAME            0
# Age              0
# gender           0
# country          0
# residence        0
# entryEXAM        0
# prevEducation    0
# studyHOURS       0
# Python           2
# DB               0
# dtype: int64

# %%
df['Python']=df['Python'].fillna(df['Python'].mean())

# %%
df.isnull().sum()
# Out:
# fNAME            0
# lNAME            0
# Age              0
# gender           0
# country          0
# residence        0
# entryEXAM        0
# prevEducation    0
# studyHOURS       0
# Python           0
# DB               0
# dtype: int64
